# %%
# %run 코로나챗봇_for_running.ipynb
# Out:
# using cached model
# using cached model
# using cached model

# %%
inp = input()
covidbertwans(inp)
# Out:
# 올바른 손씻기 방법
# 질문:  정확한 손 씻는 규칙이 어떻게 되나요?
#
# 답변:
# ○ 손을 씻을 때는 손바닥, 손등, 손가락 사이, 두 손 모아, 엄지손가락, 손톱 밑까지 꼼꼼하게 씻는 것이 중요합니다．
#
# 올바른 손씻기 방법:
# http://www.cdc.go.kr/gallery.es?mid=a20503020000&bid=0003&b_list=9&act=view&list_no=144820&nPage=1&vlist_no_npage=2&keyField=&keyWord=&orderby=
# 출처:  http://www.cdc.go.kr/gallery.es?mid=a20503020000&bid=0003&b_list=9&act=view&list_no=144820&nPage=1&vlist_no_npage=2&keyField=&keyWord=&orderby=
#
# 비슷한 질문들도 있어요:
# 1 .  COVID-19 예방을 위해 어떻게 손을 씻어야하나요?
# 2 .  올바른 기침 예절에 대해 알려주세요
# 3 .  손 씻는 시간과 주기는?
# 4 .  손소독제 올바른 사용법은 무엇인가요?

# %%
torch.__version__
# Out:
# '1.6.0'
